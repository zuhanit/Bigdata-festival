# %% [markdown]
# # 파일을 다 받아온다
# # 데이터를 처리한다
# # 끝

# %% [markdown]
# 1. 일반 투자자 대상
# 2. 일반투자자 중에서 재무관련정보에 무지한 사람들
# 3. 재무제표 << 기본 베이스
# 4. 플러스 알파
# 5. 모든 정보를 발기한 이후로 모두
# 6.

# %% [markdown]
# 프로토타입
# - 국내만
# - 재무재표만 일단 시각화
# - 증시지수 : 코스피 코스닥 노스닥 다우 시장지표들따오고

# %% [markdown]
# 재무재표
# - 재무상태표안중요함
# - 손익계산서(i/s)>
#     - 매출액
#     - 영업이익
#     - 비용
#     - 손익, 포괄손익

# %% [markdown]
# 증시 지수
# - 아시아 유럽 미국
