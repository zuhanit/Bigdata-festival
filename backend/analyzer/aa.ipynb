# %%
import matplotlib.pyplot
import numpy
import pandas

profits_df = pandas.read_excel('data/excel/2021_1Q_손익계산서.xlsx')
names = []
for name, item in profits_df.iterrows():
  if item['회사명'] not in names:
    names.append(item['회사명'])
